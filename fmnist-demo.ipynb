# %%
import torch
import gc
import numpy as np
from workflows import *

# %%
max_out_dim = 10
out_dims = np.arange(1, max_out_dim+1)
DSET = 'fmnist'
TASK = 'class'
HEAD = 'logreg'
METRIC = 'accuracy'

# %%
single_trial_workflow(1, 2, 'pca', DSET, TASK, HEAD, METRIC)
# Out:
# 0.4521
