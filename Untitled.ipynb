# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3060 Laptop GPU'

# %%
torch.rand(5,3)
# Out:
# tensor([[0.7671, 0.0486, 0.9065],
#         [0.9729, 0.3985, 0.3325],
#         [0.1430, 0.7192, 0.2246],
#         [0.7936, 0.8364, 0.1816],
#         [0.7195, 0.1046, 0.6414]])
